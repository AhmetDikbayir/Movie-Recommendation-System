# %%
#Description: Build a movie recommendation engine using python

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# ## Import Data

# %%
df=pd.read_csv('MoviesData.csv')

# %%
df.head()
# Out:
#    index  tmdbId                           title  release_year release_day  \
# 0      0  119450  Dawn of the Planet of the Apes          2014    Thursday
# 1      1    2124                  Color of Night          1994      Friday
# 2      2   75656                  Now You See Me          2013   Wednesday
# 3      3     567                     Rear Window          1954      Sunday
# 4      4   24428                    The Avengers          2012   Wednesday
#
#                                   genres original_language  runtime  \
# 0  Science Fiction|Action|Drama|Thriller          English     130.0
# 1         Drama|Mystery|Romance|Thriller          English     121.0
# 2                         Thriller|Crime          English     115.0
# 3                 Drama|Mystery|Thriller          English     112.0
# 4       Science Fiction|Action|Adventure          English     143.0
#
#                                              content  \
# 0  A group of scientists in San Francisco struggl...
# 1  When New York psychiatrist Bill Capa visits Lo...
# 2  An FBI agent and an Interpol detective track a...
# 3  Professional photographer L.B. "Jeff" Jeffries...
# 4  When an unexpected enemy emerges and threatens...
#
#                                 production_companies  ...  \
# 0  Ingenious Media|Chernin Entertainment|TSG Ente...  ...
# 1  Hollywood Pictures|Cinergi Pictures Entertainment  ...
# 2  Summit Entertainment|K/O Paper Products|SOIXAN...  ...
# 3                                 Paramount Pictures  ...
# 4                  Paramount Pictures|Marvel Studios  ...
#
#               production_countries    status popularity vote_average  \
# 0         United States of America  Released  75.385211          7.3
# 1         United States of America  Released  14.228963          5.4
# 2  United States of America|France  Released  17.852022          7.3
# 3         United States of America  Released  17.911314          8.2
# 4         United States of America  Released  89.887648          7.4
#
#    vote_count                                           keywords  \
# 0      4511.0  ['leader', 'colony', 'post-apocalyptic', 'dyst...
# 1       117.0  ['suicide', 'california', 'sex', 'secret ident...
# 2      5635.0  ['paris', 'bank', 'secret', 'fbi', 'vault', 'm...
# 3      1531.0  ['nurse', 'photographer', 'suspicion of murder...
# 4     12000.0  ['new york', 'shield', 'marvel comic', 'superh...
#
#                                                 cast          director  \
# 0  Andy Serkis|Jason Clarke|Gary Oldman|Keri Russ...       Matt Reeves
# 1  Bruce Willis|Jane March|Rubén Blades|Lesley An...      Richard Rush
# 2  Jesse Eisenberg|Mark Ruffalo|Woody Harrelson|M...   Louis Leterrier
# 3  James Stewart|Grace Kelly|Wendell Corey|Thelma...  Alfred Hitchcock
# 4  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...       Joss Whedon
#
#   rating_count mean_rating
# 0        341.0    4.054252
# 1        324.0    4.256173
# 2        311.0    4.487138
# 3        304.0    4.138158
# 4        291.0    4.221649
#
# [5 rows x 22 columns]

# %%
#Get a count of the number of rows/movies in the dataset and the number of the columns 
df.shape
# Out:
# (9081, 22)

# %%
#Create a list of important columns for the recommendation engine
columns = ['title','genres', 'director', 'cast']

# %%
df2= df[columns]
df2.head()
# Out:
#                             title                                 genres  \
# 0  Dawn of the Planet of the Apes  Science Fiction|Action|Drama|Thriller
# 1                  Color of Night         Drama|Mystery|Romance|Thriller
# 2                  Now You See Me                         Thriller|Crime
# 3                     Rear Window                 Drama|Mystery|Thriller
# 4                    The Avengers       Science Fiction|Action|Adventure
#
#            director                                               cast
# 0       Matt Reeves  Andy Serkis|Jason Clarke|Gary Oldman|Keri Russ...
# 1      Richard Rush  Bruce Willis|Jane March|Rubén Blades|Lesley An...
# 2   Louis Leterrier  Jesse Eisenberg|Mark Ruffalo|Woody Harrelson|M...
# 3  Alfred Hitchcock  James Stewart|Grace Kelly|Wendell Corey|Thelma...
# 4       Joss Whedon  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...

# %%
#Check for any missing values in the important columns
df2.isnull().sum()
# Out:
# title        0
# genres      35
# director     0
# cast        90
# dtype: int64

# %%
df2.dropna(how = 'any', inplace=True)
# Out:
# C:\Users\Lenovo Pc\AppData\Local\Temp\ipykernel_1212\2691103899.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.dropna(how = 'any', inplace=True)

# %%
df2.isnull().sum()
# Out:
# title       0
# genres      0
# director    0
# cast        0
# dtype: int64

# %%
df2.shape
# Out:
# (8962, 4)

# %% [markdown]
# ### df2 and df merged

# %%
df3= pd.merge(df,df2)
df3.head()
# Out:
#    index  tmdbId                           title  release_year release_day  \
# 0      0  119450  Dawn of the Planet of the Apes          2014    Thursday
# 1      1    2124                  Color of Night          1994      Friday
# 2      2   75656                  Now You See Me          2013   Wednesday
# 3      3     567                     Rear Window          1954      Sunday
# 4      4   24428                    The Avengers          2012   Wednesday
#
#                                   genres original_language  runtime  \
# 0  Science Fiction|Action|Drama|Thriller          English     130.0
# 1         Drama|Mystery|Romance|Thriller          English     121.0
# 2                         Thriller|Crime          English     115.0
# 3                 Drama|Mystery|Thriller          English     112.0
# 4       Science Fiction|Action|Adventure          English     143.0
#
#                                              content  \
# 0  A group of scientists in San Francisco struggl...
# 1  When New York psychiatrist Bill Capa visits Lo...
# 2  An FBI agent and an Interpol detective track a...
# 3  Professional photographer L.B. "Jeff" Jeffries...
# 4  When an unexpected enemy emerges and threatens...
#
#                                 production_companies  ...  \
# 0  Ingenious Media|Chernin Entertainment|TSG Ente...  ...
# 1  Hollywood Pictures|Cinergi Pictures Entertainment  ...
# 2  Summit Entertainment|K/O Paper Products|SOIXAN...  ...
# 3                                 Paramount Pictures  ...
# 4                  Paramount Pictures|Marvel Studios  ...
#
#               production_countries    status popularity vote_average  \
# 0         United States of America  Released  75.385211          7.3
# 1         United States of America  Released  14.228963          5.4
# 2  United States of America|France  Released  17.852022          7.3
# 3         United States of America  Released  17.911314          8.2
# 4         United States of America  Released  89.887648          7.4
#
#    vote_count                                           keywords  \
# 0      4511.0  ['leader', 'colony', 'post-apocalyptic', 'dyst...
# 1       117.0  ['suicide', 'california', 'sex', 'secret ident...
# 2      5635.0  ['paris', 'bank', 'secret', 'fbi', 'vault', 'm...
# 3      1531.0  ['nurse', 'photographer', 'suspicion of murder...
# 4     12000.0  ['new york', 'shield', 'marvel comic', 'superh...
#
#                                                 cast          director  \
# 0  Andy Serkis|Jason Clarke|Gary Oldman|Keri Russ...       Matt Reeves
# 1  Bruce Willis|Jane March|Rubén Blades|Lesley An...      Richard Rush
# 2  Jesse Eisenberg|Mark Ruffalo|Woody Harrelson|M...   Louis Leterrier
# 3  James Stewart|Grace Kelly|Wendell Corey|Thelma...  Alfred Hitchcock
# 4  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...       Joss Whedon
#
#   rating_count mean_rating
# 0        341.0    4.054252
# 1        324.0    4.256173
# 2        311.0    4.487138
# 3        304.0    4.138158
# 4        291.0    4.221649
#
# [5 rows x 22 columns]

# %%
df3.shape
# Out:
# (8962, 22)

# %%
df3.reset_index(inplace=True)

# %%
df3.rename({'level_0':'indexx'}, axis = 'columns', inplace=True)

# %%
#Create a function to combine the values of the important columns into a single string
def get_important_features(data):
    important_features = []
    for i in range(0,data.shape[0]):
        important_features.append(data['director'][i]+' '+data['genres'][i]+' '+data['title'][i]+ ' '+data['cast'][i])
    return important_features

# %%
df3.head()
# Out:
#    indexx  index  tmdbId                           title  release_year  \
# 0       0      0  119450  Dawn of the Planet of the Apes          2014
# 1       1      1    2124                  Color of Night          1994
# 2       2      2   75656                  Now You See Me          2013
# 3       3      3     567                     Rear Window          1954
# 4       4      4   24428                    The Avengers          2012
#
#   release_day                                 genres original_language  \
# 0    Thursday  Science Fiction|Action|Drama|Thriller          English
# 1      Friday         Drama|Mystery|Romance|Thriller          English
# 2   Wednesday                         Thriller|Crime          English
# 3      Sunday                 Drama|Mystery|Thriller          English
# 4   Wednesday       Science Fiction|Action|Adventure          English
#
#    runtime                                            content  ...  \
# 0    130.0  A group of scientists in San Francisco struggl...  ...
# 1    121.0  When New York psychiatrist Bill Capa visits Lo...  ...
# 2    115.0  An FBI agent and an Interpol detective track a...  ...
# 3    112.0  Professional photographer L.B. "Jeff" Jeffries...  ...
# 4    143.0  When an unexpected enemy emerges and threatens...  ...
#
#               production_countries    status  popularity vote_average  \
# 0         United States of America  Released   75.385211          7.3
# 1         United States of America  Released   14.228963          5.4
# 2  United States of America|France  Released   17.852022          7.3
# 3         United States of America  Released   17.911314          8.2
# 4         United States of America  Released   89.887648          7.4
#
#   vote_count                                           keywords  \
# 0     4511.0  ['leader', 'colony', 'post-apocalyptic', 'dyst...
# 1      117.0  ['suicide', 'california', 'sex', 'secret ident...
# 2     5635.0  ['paris', 'bank', 'secret', 'fbi', 'vault', 'm...
# 3     1531.0  ['nurse', 'photographer', 'suspicion of murder...
# 4    12000.0  ['new york', 'shield', 'marvel comic', 'superh...
#
#                                                 cast          director  \
# 0  Andy Serkis|Jason Clarke|Gary Oldman|Keri Russ...       Matt Reeves
# 1  Bruce Willis|Jane March|Rubén Blades|Lesley An...      Richard Rush
# 2  Jesse Eisenberg|Mark Ruffalo|Woody Harrelson|M...   Louis Leterrier
# 3  James Stewart|Grace Kelly|Wendell Corey|Thelma...  Alfred Hitchcock
# 4  Robert Downey Jr.|Chris Evans|Mark Ruffalo|Chr...       Joss Whedon
#
#   rating_count mean_rating
# 0        341.0    4.054252
# 1        324.0    4.256173
# 2        311.0    4.487138
# 3        304.0    4.138158
# 4        291.0    4.221649
#
# [5 rows x 23 columns]

# %%
#Create a column to hold the combined strings
df3['important_features'] = get_important_features(df3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [139], in <cell line: 2>()
#       1 #Create a column to hold the combined strings
# ----> 2 df3['important_features'] = get_important_features(df3)
#
# Input In [137], in get_important_features(data)
#       3 important_features = []
#       4 for i in range(0,data.shape[0]):
# ----> 5     important_features.append(data['director'][i]+' '+data['genres'][i]+' '+data['title'][i]+ ' '+data['cast'][i])
#       6 return important_features
#
# TypeError: can only concatenate str (not "float") to str

# %%
#Show the data
df3.head(3)
# Out:
#    indexx  index  tmdbId                           title  release_year  \
# 0       0      0  119450  Dawn of the Planet of the Apes          2014
# 1       1      1    2124                  Color of Night          1994
# 2       2      2   75656                  Now You See Me          2013
#
#   release_day                                 genres original_language  \
# 0    Thursday  Science Fiction|Action|Drama|Thriller          English
# 1      Friday         Drama|Mystery|Romance|Thriller          English
# 2   Wednesday                         Thriller|Crime          English
#
#    runtime                                            content  ...    status  \
# 0    130.0  A group of scientists in San Francisco struggl...  ...  Released
# 1    121.0  When New York psychiatrist Bill Capa visits Lo...  ...  Released
# 2    115.0  An FBI agent and an Interpol detective track a...  ...  Released
#
#    popularity  vote_average vote_count  \
# 0   75.385211           7.3     4511.0
# 1   14.228963           5.4      117.0
# 2   17.852022           7.3     5635.0
#
#                                             keywords  \
# 0  ['leader', 'colony', 'post-apocalyptic', 'dyst...
# 1  ['suicide', 'california', 'sex', 'secret ident...
# 2  ['paris', 'bank', 'secret', 'fbi', 'vault', 'm...
#
#                                                 cast         director  \
# 0  Andy Serkis|Jason Clarke|Gary Oldman|Keri Russ...      Matt Reeves
# 1  Bruce Willis|Jane March|Rubén Blades|Lesley An...     Richard Rush
# 2  Jesse Eisenberg|Mark Ruffalo|Woody Harrelson|M...  Louis Leterrier
#
#    rating_count mean_rating                                 important_features
# 0         341.0    4.054252  Matt Reeves Science Fiction|Action|Drama|Thril...
# 1         324.0    4.256173  Richard Rush Drama|Mystery|Romance|Thriller Co...
# 2         311.0    4.487138      Louis Leterrier Thriller|Crime Now You See Me
#
# [3 rows x 24 columns]

# %%
#Convert the text to a matrix of token counts
cm = CountVectorizer().fit_transform(df3['important_features'])

# %%
#Get the cosine similarity matrix from the count matrix
cs = cosine_similarity(cm)

#Print the cosine similarity matrix
print(cs)
# Out:
# [[1.         0.31426968 0.08333333 ... 0.16666667 0.15713484 0.15713484]
#  [0.31426968 1.         0.11785113 ... 0.         0.11111111 0.        ]
#  [0.08333333 0.11785113 1.         ... 0.         0.         0.        ]
#  ...
#  [0.16666667 0.         0.         ... 1.         0.11785113 0.23570226]
#  [0.15713484 0.11111111 0.         ... 0.11785113 1.         0.11111111]
#  [0.15713484 0.         0.         ... 0.23570226 0.11111111 1.        ]]

# %%
#Get the shape of the cosine similarity matrix
cs.shape
# Out:
# (9046, 9046)

# %%
#Get the title of one movie
title='Dawn of the Planet of the Apes'
title2= 'Get Him to the Greek'

#Find the movie id
movie_id= df3[df3.title == title]['index'].values[0]
movie_id2= df3[df3.title == title2]['indexx'].values[0]

# %%
movie_id2
# Out:
# 9043

# %%
#Create a list of enumerations for the similarity score [ (movie_id, similarity score), (...)]
scores = list(enumerate(cs[movie_id]))
scores2 = list(enumerate(cs[movie_id2]))

# %%
#Sort the list
sorted_scores =  sorted(scores, key= lambda x: x[1], reverse = True)
), (7988, 0.3162277660168379), (8258, 0.3162277660168379), (8442, 0.3162277660168379), (8821, 0.3162277660168379), (8833, 0.3162277660168379), (2076, 0.30618621784789724), (2132, 0.30618621784789724), (2385, 0.30618621784789724), (2528, 0.30618621784789724), (2628, 0.30618621784789724), (3869, 0.30618621784789724), (4423, 0.30618621784789724), (4581, 0.30618621784789724), (4672, 0.30618621784789724), (4732, 0.30618621784789724), (5200, 0.30618621784789724), (5226, 0.30618621784789724), (5440, 0.30618621784789724), (5702, 0.30618621784789724), (6139, 0.30618621784789724), (6300, 0.30618621784789724), (7361, 0.30618621784789724), (7669, 0.30618621784789724), (7688, 0.30618621784789724), (7730, 0.30618621784789724), (7881, 0.30618621784789724), (139, 0.294174202707276), (639, 0.294174202707276), (977, 0.294174202707276), (1670, 0.294174202707276), (2315, 0.294174202707276), (3711, 0.294174202707276), (4959, 0.294174202707276), (5201, 0.294174202707276), (6821, 0.294174202707276), (7539, 0.294174202707276), (9020, 0.294174202707276), (504, 0.2886751345948129), (568, 0.2886751345948129), (678, 0.2886751345948129), (680, 0.2886751345948129), (743, 0.2886751345948129), (811, 0.2886751345948129), (1069, 0.2886751345948129), (1080, 0.2886751345948129), (1206, 0.2886751345948129), (1415, 0.2886751345948129), (1769, 0.2886751345948129), (1793, 0.2886751345948129), (1822, 0.2886751345948129), (1916, 0.2886751345948129), (1951, 0.2886751345948129), (2070, 0.2886751345948129), (2199, 0.2886751345948129), (2271, 0.2886751345948129), (2335, 0.2886751345948129), (2336, 0.2886751345948129), (2452, 0.2886751345948129), (2535, 0.2886751345948129), (2986, 0.2886751345948129), (3067, 0.2886751345948129), (3127, 0.2886751345948129), (3173, 0.2886751345948129), (3180, 0.2886751345948129), (3196, 0.2886751345948129), (3222, 0.2886751345948129), (3239, 0.2886751345948129), (3256, 0.2886751345948129), (3268, 0.2886751345948129), (3291, 0.2886751345948129), (3404, 0.2886751345948129), (3408, 0.2886751345948129), (3413, 0.2886751345948129), (3440, 0.288675 ...

# %%
#Create a loop to print the 7 similar movies
j=0
print('The 7 most recommended movies to', title, 'are: \n')
for item in sorted_scores:
    movie_title = df3[df3.indexx == item[0]]['title'].values[0]
    print(j+1, movie_title)
    j+=1
    if j>6:
        break
# Out:
# The 7 most recommended movies to Dawn of the Planet of the Apes are:
#
# 1 Rise of the Planet of the Apes
# 2 Conquest of the Planet of the Apes
# 3 Planet of the Apes
# 4 Planet of the Apes
# 5 Battle for the Planet of the Apes
# 6 Escape from the Planet of the Apes
# 7 Until the End of the World

# %%
#Create a loop to print the 7 similar movies
j=0
print('The 7 most recommended movies to', title, 'are: \n')
for item in sorted_scores2:
    movie_title = df3[df3.indexx == item[0]]['title'].values[0]
    print(j+1, movie_title)
    j+=1
    if j>6:
        break
# Out:
# The 7 most recommended movies to Dawn of the Planet of the Apes are:
#
# 1 The Five-Year Engagement
# 2 Neighbors
# 3 Neighbors 2: Sorority Rising
# 4 The History Boys
# 5 Welcome to the Jungle
# 6 Forgetting Sarah Marshall
# 7 Back to the Beach
